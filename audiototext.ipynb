# %% [markdown]
# <a href="https://colab.research.google.com/github/preett14/Advaitraining/blob/main/audiototext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome to google colab')
